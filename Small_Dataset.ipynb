# %%
import numpy as np
import pandas as pd 
import tensorflow as tf
import nltk
import seaborn as sns
import re
import matplotlib.pyplot as plt
from tqdm import tqdm

from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
raw_data = pd.read_csv('small_dataset.csv') # Text data
EMBEDDING_FILE = f'glove.6B.100d.txt' # GloVe file path
raw_data.head()
# Out:
#                                                 Text  Emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
# Target Classes (Labels)
plt.figure(figsize=(15,5))

sns.countplot(raw_data['Emotion'])
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Emotion', ylabel='count'>

# %%
raw_data = raw_data.dropna()
X = raw_data.drop('Emotion',axis=1) # input
y = raw_data['Emotion'] # output

messages = X.copy()
messages.reset_index(inplace=True)

# %%
nltk.download('stopwords')
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Elusive\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []
for i in tqdm(range(0, len(messages))):
    review = re.sub('[^a-zA-Z]', ' ', messages['Text'][i]) #remove Special Characters
    review = review.lower() #lower case 
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')] #remove stopwords
    review = ' '.join(review)
    corpus.append(review)
# Out:
# 100%|██████████| 21459/21459 [01:32<00:00, 231.01it/s]

# %%
# Saving Progress
if len(corpus) > 10000:
    corpus_df = pd.DataFrame({'Text': corpus})
    corpus_df.to_csv('small_corpus.csv')
print(len(corpus))
corpus[-10:]
# Out:
# 21459
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
# Loading Progress
temp = pd.read_csv('small_corpus.csv')
temp['Emotion'] = raw_data['Emotion'].values
temp['Text'] = temp['Text'].str.replace('\d+', '')
temp = temp.dropna()
# Out:
# <ipython-input-10-fd0c2d5c437e>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   temp['Text'] = temp['Text'].str.replace('\d+', '')

# %%
temp_list = temp['Text'].tolist()
print(len(temp_list))
print(temp.shape)
temp_list[-10:]
# Out:
# 21458
# (21458, 3)
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
X = temp.drop('Emotion', axis=1) #input
y = temp['Emotion'] #output

# %%
corpus = []
corpus = temp_list
print(len(corpus))
corpus[-10:]
# Out:
# 21458
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
# Creating the dictionary with word as key and pretrained-value array as value
def get_coefs(word,*arr):
    return word, np.asarray(arr, dtype='float32')

embeddings_index = dict(get_coefs(*o.strip().split()) for o in open(EMBEDDING_FILE, encoding="utf8"))


# Calculate MEAN and Standard-Deviation for the pre-trained weights
all_embeddings = np.stack(embeddings_index.values())
embedding_mean, embedding_std = all_embeddings.mean(), all_embeddings.std()
print(embedding_mean, embedding_std)
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\IPython\core\interactiveshell.py:3357: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# 0.004451992 0.4081574

# %%
vocabulary_size = 13000 # Vocabulary size
embed_size = 100 #word vector size

tokenizer = Tokenizer(num_words = vocabulary_size)
tokenizer.fit_on_texts(list(corpus))

# %%
word_index = tokenizer.word_index # total words in the corpus
nb_words = min(vocabulary_size, len(word_index))

# Initialize weight matrix for embedding layer
embedding_matrix = np.random.normal(embedding_mean, embedding_std, (nb_words, embed_size)) 

for word, i in word_index.items():
    if i >= vocabulary_size:
        continue #skip the words if vocab size is reached
    embedding_vector = embeddings_index.get(word) #extracting the pre-trained values from GloVe
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
# Contains the pretrained GloVe weights for the words
len(embedding_matrix)
# Out:
# 13000

# %%
# One hot representation for input
onehot_repr=[one_hot(words, vocabulary_size) for words in corpus]

# Finding max words
l = 0
for x in corpus:
    l = max(l, len(x.split(' ')))

# Padding the sequences for input
sentence_length = l
embedded_docs = pad_sequences(onehot_repr, padding = 'pre', maxlen = sentence_length)
print(embedded_docs)
# Out:
# [[    0     0     0 ...  5681  1033  7146]
#  [    0     0     0 ...  6994  9702    96]
#  [    0     0     0 ...  1033 12934  1892]
#  ...
#  [    0     0     0 ...  9165  9268  7594]
#  [    0     0     0 ...    45  7594  7981]
#  [    0     0     0 ...     0  7594 11446]]

# %%
# Encoding the target outputs to integers
label_encoder = preprocessing.LabelEncoder()

X_final = np.array(embedded_docs) #input to array
y = label_encoder.fit_transform(y)
y_final=np.array(y)
print(y_final)

X_final.shape, y_final.shape
# Out:
# [4 4 0 ... 1 1 1]
# ((21458, 35), (21458,))

# %%
# Train-Test split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size = 0.2, random_state = 42) 

# Train-Validation split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.1, random_state = 21)

# %%
# Creating model
model = Sequential()
model.add(Embedding(vocabulary_size, embed_size, weights=[embedding_matrix]))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.3))
model.add(Dense(64, activation = 'relu', kernel_regularizer = tf.keras.regularizers.L1(0.01))) #L1 regularization
model.add(Dropout(0.3))
model.add(Dense(6,activation = 'softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, None, 100)         1300000
# _________________________________________________________________
# dropout_18 (Dropout)         (None, None, 100)         0
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 128)               84480
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 6)                 390
# =================================================================
# Total params: 1,393,126
# Trainable params: 1,393,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_save = ModelCheckpoint('small_weights.h5', save_best_only = True, save_weights_only = True, monitor = 'val_loss', mode = 'min', verbose = 1)

history = model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 40, batch_size = 64, callbacks = [model_save])
# Out:
# Epoch 1/40
# 242/242 [==============================] - 9s 25ms/step - loss: 3.5914 - accuracy: 0.3193 - val_loss: 1.6667 - val_accuracy: 0.3273
#
# Epoch 00001: val_loss improved from inf to 1.66671, saving model to small_weights.h5
# Epoch 2/40
# 242/242 [==============================] - 5s 19ms/step - loss: 1.6306 - accuracy: 0.3192 - val_loss: 1.6328 - val_accuracy: 0.2865
#
# Epoch 00002: val_loss improved from 1.66671 to 1.63279, saving model to small_weights.h5
# Epoch 3/40
# 242/242 [==============================] - 5s 21ms/step - loss: 1.6120 - accuracy: 0.3258 - val_loss: 1.6181 - val_accuracy: 0.3273
#
# Epoch 00003: val_loss improved from 1.63279 to 1.61813, saving model to small_weights.h5
# Epoch 4/40
# 242/242 [==============================] - 5s 21ms/step - loss: 1.6058 - accuracy: 0.3284 - val_loss: 1.6181 - val_accuracy: 0.3273
#
# Epoch 00004: val_loss improved from 1.61813 to 1.61808, saving model to small_weights.h5
# Epoch 5/40
# 242/242 [==============================] - 5s 21ms/step - loss: 1.6040 - accuracy: 0.3244 - val_loss: 1.6173 - val_accuracy: 0.3273
#
# Epoch 00005: val_loss improved from 1.61808 to 1.61733, saving model to small_weights.h5
# Epoch 6/40
# 242/242 [==============================] - 5s 21ms/step - loss: 1.6038 - accuracy: 0.3258 - val_loss: 1.6145 - val_accuracy: 0.3273
#
# Epoch 00006: val_loss improved from 1.61733 to 1.61453, saving model to small_weights.h5
# Epoch 7/40
# 242/242 [==============================] - 5s 19ms/step - loss: 1.6022 - accuracy: 0.3297 - val_loss: 1.6142 - val_accuracy: 0.3273
#
# Epoch 00007: val_loss improved from 1.61453 to 1.61420, saving model to small_weights.h5
# Epoch 8/40
# 242/242 [==============================] - 5s 21ms/step - loss: 1.6023 - accuracy: 0.3271 - val_loss: 1.6152 - val_accuracy: 0.3273
#
# Epoch 00008: val_loss did not improve from 1.61420
# Epoch 9/40
# 242/242 [==============================] - 5s 21ms/step - loss: 1.5333 - accuracy: 0.3308 - val_loss: 1.4081 - val_accuracy: 0.3355
#
# Epoch 00009: val_loss improved from 1.61420 to 1.40810, saving model to small_weights.h5
# Epoch 10/40
# 242/242 [==============================] - 5s 19ms/step - loss: 1.3335 - accuracy: 0.4025 - val_loss: 1.2785 - val_accuracy: 0.4170
#
# Epoch 00010: val_loss improved from 1.40810 to 1.27854, saving model to small_weights.h5
# Epoch 11/40
# 242/242 [==============================] - 5s 20ms/step - loss: 1.2354 - accuracy: 0.4665 - val_loss: 1.1826 - val_accuracy: 0.5684
#
# Epoch 00011: val_loss improved from 1.27854 to 1.18256, saving model to small_weights.h5
# Epoch 12/40
# 242/242 [==============================] - 5s 19ms/step - loss: 1.0901 - accuracy: 0.5991 - val_loss: 0.9497 - val_accuracy: 0.6738
#
# Epoch 00012: val_loss improved from 1.18256 to 0.94966, saving model to small_weights.h5
# Epoch 13/40
# 242/242 [==============================] - 5s 20ms/step - loss: 0.9070 - accuracy: 0.6962 - val_loss: 0.8285 - val_accuracy: 0.7094
#
# Epoch 00013: val_loss improved from 0.94966 to 0.82850, saving model to small_weights.h5
# Epoch 14/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.8041 - accuracy: 0.7345 - val_loss: 0.7656 - val_accuracy: 0.7321
#
# Epoch 00014: val_loss improved from 0.82850 to 0.76564, saving model to small_weights.h5
# Epoch 15/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.7400 - accuracy: 0.7552 - val_loss: 0.7517 - val_accuracy: 0.7315
#
# Epoch 00015: val_loss improved from 0.76564 to 0.75168, saving model to small_weights.h5
# Epoch 16/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.6976 - accuracy: 0.7722 - val_loss: 0.7178 - val_accuracy: 0.7373
#
# Epoch 00016: val_loss improved from 0.75168 to 0.71778, saving model to small_weights.h5
# Epoch 17/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.6656 - accuracy: 0.7751 - val_loss: 0.6960 - val_accuracy: 0.7461
#
# Epoch 00017: val_loss improved from 0.71778 to 0.69596, saving model to small_weights.h5
# Epoch 18/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.6363 - accuracy: 0.7814 - val_loss: 0.6919 - val_accuracy: 0.7472
#
# Epoch 00018: val_loss improved from 0.69596 to 0.69194, saving model to small_weights.h5
# Epoch 19/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.6135 - accuracy: 0.7852 - val_loss: 0.6789 - val_accuracy: 0.7670
#
# Epoch 00019: val_loss improved from 0.69194 to 0.67888, saving model to small_weights.h5
# Epoch 20/40
# 242/242 [==============================] - 5s 19ms/step - loss: 0.5929 - accuracy: 0.8033 - val_loss: 0.6555 - val_accuracy: 0.7868
#
# Epoch 00020: val_loss improved from 0.67888 to 0.65554, saving model to small_weights.h5
# Epoch 21/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.5701 - accuracy: 0.8238 - val_loss: 0.6475 - val_accuracy: 0.8270
#
# Epoch 00021: val_loss improved from 0.65554 to 0.64753, saving model to small_weights.h5
# Epoch 22/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.5379 - accuracy: 0.8534 - val_loss: 0.6137 - val_accuracy: 0.8550
#
# Epoch 00022: val_loss improved from 0.64753 to 0.61370, saving model to small_weights.h5
# Epoch 23/40
# 242/242 [==============================] - 5s 20ms/step - loss: 0.5012 - accuracy: 0.8773 - val_loss: 0.5834 - val_accuracy: 0.8690
#
# Epoch 00023: val_loss improved from 0.61370 to 0.58342, saving model to small_weights.h5
# Epoch 24/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.4592 - accuracy: 0.8974 - val_loss: 0.5743 - val_accuracy: 0.8730
#
# Epoch 00024: val_loss improved from 0.58342 to 0.57430, saving model to small_weights.h5
# Epoch 25/40
# 242/242 [==============================] - 5s 19ms/step - loss: 0.4385 - accuracy: 0.9033 - val_loss: 0.5622 - val_accuracy: 0.8701
#
# Epoch 00025: val_loss improved from 0.57430 to 0.56221, saving model to small_weights.h5
# Epoch 26/40
# 242/242 [==============================] - 5s 19ms/step - loss: 0.4208 - accuracy: 0.9089 - val_loss: 0.5515 - val_accuracy: 0.8777
#
# Epoch 00026: val_loss improved from 0.56221 to 0.55152, saving model to small_weights.h5
# Epoch 27/40
# 242/242 [==============================] - 5s 20ms/step - loss: 0.4078 - accuracy: 0.9150 - val_loss: 0.5476 - val_accuracy: 0.8771
#
# Epoch 00027: val_loss improved from 0.55152 to 0.54758, saving model to small_weights.h5
# Epoch 28/40
# 242/242 [==============================] - 5s 20ms/step - loss: 0.3887 - accuracy: 0.9197 - val_loss: 0.5354 - val_accuracy: 0.8794
#
# Epoch 00028: val_loss improved from 0.54758 to 0.53540, saving model to small_weights.h5
# Epoch 29/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.3702 - accuracy: 0.9263 - val_loss: 0.5246 - val_accuracy: 0.8829
#
# Epoch 00029: val_loss improved from 0.53540 to 0.52462, saving model to small_weights.h5
# Epoch 30/40
# 242/242 [==============================] - 5s 20ms/step - loss: 0.3565 - accuracy: 0.9301 - val_loss: 0.5293 - val_accuracy: 0.8789
#
# Epoch 00030: val_loss did not improve from 0.52462
# Epoch 31/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.3496 - accuracy: 0.9311 - val_loss: 0.5060 - val_accuracy: 0.8905
#
# Epoch 00031: val_loss improved from 0.52462 to 0.50602, saving model to small_weights.h5
# Epoch 32/40
# 242/242 [==============================] - 5s 19ms/step - loss: 0.3392 - accuracy: 0.9337 - val_loss: 0.5062 - val_accuracy: 0.8888
#
# Epoch 00032: val_loss did not improve from 0.50602
# Epoch 33/40
# 242/242 [==============================] - 7s 27ms/step - loss: 0.3253 - accuracy: 0.9365 - val_loss: 0.5316 - val_accuracy: 0.8870
#
# Epoch 00033: val_loss did not improve from 0.50602
# Epoch 34/40
# 242/242 [==============================] - 8s 31ms/step - loss: 0.3150 - accuracy: 0.9414 - val_loss: 0.5273 - val_accuracy: 0.8870
#
# Epoch 00034: val_loss did not improve from 0.50602
# Epoch 35/40
# 242/242 [==============================] - 8s 31ms/step - loss: 0.3088 - accuracy: 0.9426 - val_loss: 0.5323 - val_accuracy: 0.8847
#
# Epoch 00035: val_loss did not improve from 0.50602
# Epoch 36/40
# 242/242 [==============================] - 7s 30ms/step - loss: 0.3028 - accuracy: 0.9439 - val_loss: 0.5456 - val_accuracy: 0.8812
#
# Epoch 00036: val_loss did not improve from 0.50602
# Epoch 37/40
# 242/242 [==============================] - 7s 30ms/step - loss: 0.2958 - accuracy: 0.9477 - val_loss: 0.5573 - val_accuracy: 0.8888
#
# Epoch 00037: val_loss did not improve from 0.50602
# Epoch 38/40
# 242/242 [==============================] - 8s 32ms/step - loss: 0.2843 - accuracy: 0.9487 - val_loss: 0.5435 - val_accuracy: 0.8800
#
# Epoch 00038: val_loss did not improve from 0.50602
# Epoch 39/40
# 242/242 [==============================] - 8s 32ms/step - loss: 0.2771 - accuracy: 0.9531 - val_loss: 0.5334 - val_accuracy: 0.8853
#
# Epoch 00039: val_loss did not improve from 0.50602
# Epoch 40/40
# 242/242 [==============================] - 8s 31ms/step - loss: 0.2763 - accuracy: 0.9511 - val_loss: 0.5442 - val_accuracy: 0.8853
#
# Epoch 00040: val_loss did not improve from 0.50602

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#Load the best weights
model.load_weights('small_weights.h5')

# %%
y_pred = model.predict_classes(X_test)
print(y_pred)
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# [1 1 4 ... 4 2 3]

# %%
#Accuracy score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8888630009319665

# %%
#Classification report
print(classification_report(y_test, y_pred, digits = 5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.87438   0.88908   0.88167       595
#            1    0.83774   0.88951   0.86285       534
#            2    0.92511   0.90323   0.91404      1395
#            3    0.74294   0.79456   0.76788       331
#            4    0.94113   0.92619   0.93360      1260
#            5    0.73780   0.68362   0.70968       177
#
#     accuracy                        0.88886      4292
#    macro avg    0.84318   0.84770   0.84495      4292
# weighted avg    0.89014   0.88886   0.88923      4292

# %%
#Confusion Matrix
print('Confusion Matrix')
print(sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, fmt="d"))
# Out:
# Confusion Matrix
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
# Mapping of target classes using label-encoder
le_name_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(le_name_mapping)

emotional_class_mapping = []
for item in le_name_mapping.items():
    # print(key)
    emotional_class_mapping.append(item[0])

# print(emotional_class_mapping)
# Out:
# {'anger': 0, 'fear': 1, 'happy': 2, 'love': 3, 'sadness': 4, 'surprise': 5}

# %%
def predict_emotion(arg_string):
    review = re.sub('[^a-zA-Z]', ' ', arg_string)
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    onehot_repr = [one_hot(review, vocabulary_size)] 
    embed = pad_sequences(onehot_repr, padding='pre', maxlen = sentence_length)
    predicti = model.predict(embed)
    return emotional_class_mapping[np.argmax(predicti)]

# %%
predict_emotion('I am very happy and joyful today')
# Out:
# 'happy'

# %%
predict_emotion('Oh I love it')
# Out:
# 'surprise'

# %%
predict_emotion('The teacher is intimidating and scary')
# Out:
# 'fear'

# %%
predict_emotion('I am depressed')
# Out:
# 'sadness'

# %%
predict_emotion('I am quite furious')
# Out:
# 'anger'
