# %%
import numpy as np
import pandas as pd 
import tensorflow as tf
import nltk
import seaborn as sns
import re
import matplotlib.pyplot as plt
from tqdm import tqdm

from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
raw_data = pd.read_csv('small_dataset.csv') # Text data
EMBEDDING_FILE = f'glove.6B.100d.txt' # GloVe file path
raw_data.head()
# Out:
#                                                 Text  Emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
# Target Classes (Labels)
plt.figure(figsize=(15,5))

sns.countplot(raw_data['Emotion'])
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Emotion', ylabel='count'>

# %%
raw_data = raw_data.dropna()
X = raw_data.drop('Emotion',axis=1) # input
y = raw_data['Emotion'] # output

messages = X.copy()
messages.reset_index(inplace=True)

# %%
nltk.download('stopwords')
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Elusive\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []
for i in tqdm(range(0, len(messages))):
    review = re.sub('[^a-zA-Z]', ' ', messages['Text'][i]) #remove Special Characters
    review = review.lower() #lower case 
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')] #remove stopwords
    review = ' '.join(review)
    corpus.append(review)
# Out:
# 100%|██████████| 21459/21459 [01:32<00:00, 231.01it/s]

# %%
# Saving Progress
if len(corpus) > 10000:
    corpus_df = pd.DataFrame({'Text': corpus})
    corpus_df.to_csv('small_corpus.csv')
print(len(corpus))
corpus[-10:]
# Out:
# 21459
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
# Loading Progress
temp = pd.read_csv('small_corpus.csv')
temp['Emotion'] = raw_data['Emotion'].values
temp['Text'] = temp['Text'].str.replace('\d+', '')
temp = temp.dropna()
# Out:
# <ipython-input-6-fd0c2d5c437e>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   temp['Text'] = temp['Text'].str.replace('\d+', '')

# %%
temp_list = temp['Text'].tolist()
print(len(temp_list))
print(temp.shape)
temp_list[-10:]
# Out:
# 21458
# (21458, 3)
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
X = temp.drop('Emotion', axis=1) #input
y = temp['Emotion'] #output

# %%
corpus = []
corpus = temp_list
print(len(corpus))
corpus[-10:]
# Out:
# 21458
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
# Creating the dictionary with word as key and pretrained-value array as value
def get_coefs(word,*arr):
    return word, np.asarray(arr, dtype='float32')

embeddings_index = dict(get_coefs(*o.strip().split()) for o in open(EMBEDDING_FILE, encoding="utf8"))


# Calculate MEAN and Standard-Deviation for the pre-trained weights
all_embeddings = np.stack(embeddings_index.values())
embedding_mean, embedding_std = all_embeddings.mean(), all_embeddings.std()
print(embedding_mean, embedding_std)
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\IPython\core\interactiveshell.py:3357: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# 0.004451992 0.4081574

# %%
vocabulary_size = 13000 # Vocabulary size
embed_size = 100 #word vector size

tokenizer = Tokenizer(num_words = vocabulary_size)
tokenizer.fit_on_texts(list(corpus))

# %%
word_index = tokenizer.word_index # total words in the corpus
nb_words = min(vocabulary_size, len(word_index))

# Initialize weight matrix for embedding layer
embedding_matrix = np.random.normal(embedding_mean, embedding_std, (nb_words, embed_size)) 

for word, i in word_index.items():
    if i >= vocabulary_size:
        continue #skip the words if vocab size is reached
    embedding_vector = embeddings_index.get(word) #extracting the pre-trained values from GloVe
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
# Contains the pretrained GloVe weights for the words
len(embedding_matrix)
# Out:
# 13000

# %%
# One hot representation for input
onehot_repr = [one_hot(words, vocabulary_size) for words in corpus]

# Finding max words
l = 0
for x in corpus:
    l = max(l, len(x.split(' ')))

# Padding the sequences for input
sentence_length = l
embedded_docs = pad_sequences(onehot_repr, padding = 'pre', maxlen = sentence_length)
print(embedded_docs)
# Out:
# [[    0     0     0 ...  5015  4934  7015]
#  [    0     0     0 ...  6486  9363 10485]
#  [    0     0     0 ...  4934  5812  8623]
#  ...
#  [    0     0     0 ... 11903  1057  8283]
#  [    0     0     0 ...  7839  8283  8431]
#  [    0     0     0 ...     0  8283  5443]]

# %%
# Encoding the target outputs to integers
label_encoder = preprocessing.LabelEncoder()

X_final = np.array(embedded_docs) #input to array
y = label_encoder.fit_transform(y)
y_final=np.array(y)
print(y_final)

X_final.shape, y_final.shape
# Out:
# [4 4 0 ... 1 1 1]
# ((21458, 35), (21458,))

# %%
# Train-Test split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size = 0.2, random_state = 42) 

# Train-Validation split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.1, random_state = 21)

# %%
# Creating model
model = Sequential()
model.add(Embedding(vocabulary_size, embed_size, weights=[embedding_matrix]))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.3))
model.add(Dense(64, activation = 'relu', kernel_regularizer = tf.keras.regularizers.L1(0.01))) #L1 regularization
model.add(Dropout(0.3))
model.add(Dense(6,activation = 'softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 100)         1300000
# _________________________________________________________________
# dropout (Dropout)            (None, None, 100)         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               84480
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 1,393,126
# Trainable params: 1,393,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_save = ModelCheckpoint('small_weights.h5', save_best_only = True, save_weights_only = True, monitor = 'val_loss', mode = 'min', verbose = 1)

history = model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 40, batch_size = 64, callbacks = [model_save])
# Out:
# Epoch 1/40
# 242/242 [==============================] - 8s 21ms/step - loss: 3.5873 - accuracy: 0.3183 - val_loss: 1.6609 - val_accuracy: 0.2871
#
# Epoch 00001: val_loss improved from inf to 1.66086, saving model to small_weights.h5
# Epoch 2/40
# 242/242 [==============================] - 4s 18ms/step - loss: 1.6303 - accuracy: 0.3196 - val_loss: 1.6274 - val_accuracy: 0.3273
#
# Epoch 00002: val_loss improved from 1.66086 to 1.62742, saving model to small_weights.h5
# Epoch 3/40
# 242/242 [==============================] - 5s 19ms/step - loss: 1.6112 - accuracy: 0.3237 - val_loss: 1.6229 - val_accuracy: 0.3273
#
# Epoch 00003: val_loss improved from 1.62742 to 1.62289, saving model to small_weights.h5
# Epoch 4/40
# 242/242 [==============================] - 4s 18ms/step - loss: 1.6082 - accuracy: 0.3244 - val_loss: 1.6179 - val_accuracy: 0.3273
#
# Epoch 00004: val_loss improved from 1.62289 to 1.61794, saving model to small_weights.h5
# Epoch 5/40
# 242/242 [==============================] - 5s 20ms/step - loss: 1.6045 - accuracy: 0.3264 - val_loss: 1.6145 - val_accuracy: 0.3273
#
# Epoch 00005: val_loss improved from 1.61794 to 1.61450, saving model to small_weights.h5
# Epoch 6/40
# 242/242 [==============================] - 4s 18ms/step - loss: 1.6028 - accuracy: 0.3285 - val_loss: 1.6155 - val_accuracy: 0.3273
#
# Epoch 00006: val_loss did not improve from 1.61450
# Epoch 7/40
# 242/242 [==============================] - 5s 19ms/step - loss: 1.6002 - accuracy: 0.3236 - val_loss: 1.6060 - val_accuracy: 0.3273
#
# Epoch 00007: val_loss improved from 1.61450 to 1.60597, saving model to small_weights.h5
# Epoch 8/40
# 242/242 [==============================] - 5s 19ms/step - loss: 1.4906 - accuracy: 0.3374 - val_loss: 1.3928 - val_accuracy: 0.3896
#
# Epoch 00008: val_loss improved from 1.60597 to 1.39276, saving model to small_weights.h5
# Epoch 9/40
# 242/242 [==============================] - 5s 20ms/step - loss: 1.3302 - accuracy: 0.4101 - val_loss: 1.2825 - val_accuracy: 0.4158
#
# Epoch 00009: val_loss improved from 1.39276 to 1.28246, saving model to small_weights.h5
# Epoch 10/40
# 242/242 [==============================] - 4s 17ms/step - loss: 1.2472 - accuracy: 0.4302 - val_loss: 1.2533 - val_accuracy: 0.4287
#
# Epoch 00010: val_loss improved from 1.28246 to 1.25331, saving model to small_weights.h5
# Epoch 11/40
# 242/242 [==============================] - 4s 18ms/step - loss: 1.1927 - accuracy: 0.4376 - val_loss: 1.2044 - val_accuracy: 0.4234
#
# Epoch 00011: val_loss improved from 1.25331 to 1.20441, saving model to small_weights.h5
# Epoch 12/40
# 242/242 [==============================] - 4s 18ms/step - loss: 1.1459 - accuracy: 0.4598 - val_loss: 1.1595 - val_accuracy: 0.4648
#
# Epoch 00012: val_loss improved from 1.20441 to 1.15947, saving model to small_weights.h5
# Epoch 13/40
# 242/242 [==============================] - 4s 19ms/step - loss: 1.0998 - accuracy: 0.4837 - val_loss: 1.1203 - val_accuracy: 0.4706
#
# Epoch 00013: val_loss improved from 1.15947 to 1.12030, saving model to small_weights.h5
# Epoch 14/40
# 242/242 [==============================] - 4s 18ms/step - loss: 1.0547 - accuracy: 0.5050 - val_loss: 1.0802 - val_accuracy: 0.4939
#
# Epoch 00014: val_loss improved from 1.12030 to 1.08022, saving model to small_weights.h5
# Epoch 15/40
# 242/242 [==============================] - 5s 20ms/step - loss: 1.0000 - accuracy: 0.5578 - val_loss: 1.0061 - val_accuracy: 0.6214
#
# Epoch 00015: val_loss improved from 1.08022 to 1.00614, saving model to small_weights.h5
# Epoch 16/40
# 242/242 [==============================] - 5s 20ms/step - loss: 0.8532 - accuracy: 0.6881 - val_loss: 0.8211 - val_accuracy: 0.7129
#
# Epoch 00016: val_loss improved from 1.00614 to 0.82109, saving model to small_weights.h5
# Epoch 17/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.7484 - accuracy: 0.7394 - val_loss: 0.7610 - val_accuracy: 0.7251
#
# Epoch 00017: val_loss improved from 0.82109 to 0.76099, saving model to small_weights.h5
# Epoch 18/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.6900 - accuracy: 0.7592 - val_loss: 0.7239 - val_accuracy: 0.7327
#
# Epoch 00018: val_loss improved from 0.76099 to 0.72391, saving model to small_weights.h5
# Epoch 19/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.6481 - accuracy: 0.7692 - val_loss: 0.7104 - val_accuracy: 0.7350
#
# Epoch 00019: val_loss improved from 0.72391 to 0.71043, saving model to small_weights.h5
# Epoch 20/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.6227 - accuracy: 0.7805 - val_loss: 0.7080 - val_accuracy: 0.7467
#
# Epoch 00020: val_loss improved from 0.71043 to 0.70800, saving model to small_weights.h5
# Epoch 21/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.6065 - accuracy: 0.7876 - val_loss: 0.6920 - val_accuracy: 0.7595
#
# Epoch 00021: val_loss improved from 0.70800 to 0.69199, saving model to small_weights.h5
# Epoch 22/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.5745 - accuracy: 0.8038 - val_loss: 0.6880 - val_accuracy: 0.7618
#
# Epoch 00022: val_loss improved from 0.69199 to 0.68801, saving model to small_weights.h5
# Epoch 23/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.5538 - accuracy: 0.8107 - val_loss: 0.6714 - val_accuracy: 0.7665
#
# Epoch 00023: val_loss improved from 0.68801 to 0.67137, saving model to small_weights.h5
# Epoch 24/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.5428 - accuracy: 0.8113 - val_loss: 0.6852 - val_accuracy: 0.7711
#
# Epoch 00024: val_loss did not improve from 0.67137
# Epoch 25/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.5299 - accuracy: 0.8180 - val_loss: 0.6807 - val_accuracy: 0.7694
#
# Epoch 00025: val_loss did not improve from 0.67137
# Epoch 26/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.5173 - accuracy: 0.8267 - val_loss: 0.6707 - val_accuracy: 0.7769
#
# Epoch 00026: val_loss improved from 0.67137 to 0.67067, saving model to small_weights.h5
# Epoch 27/40
# 242/242 [==============================] - 5s 23ms/step - loss: 0.5072 - accuracy: 0.8351 - val_loss: 0.6747 - val_accuracy: 0.8043
#
# Epoch 00027: val_loss did not improve from 0.67067
# Epoch 28/40
# 242/242 [==============================] - 5s 23ms/step - loss: 0.4931 - accuracy: 0.8450 - val_loss: 0.6530 - val_accuracy: 0.8282
#
# Epoch 00028: val_loss improved from 0.67067 to 0.65298, saving model to small_weights.h5
# Epoch 29/40
# 242/242 [==============================] - 6s 23ms/step - loss: 0.4683 - accuracy: 0.8669 - val_loss: 0.6498 - val_accuracy: 0.8526
#
# Epoch 00029: val_loss improved from 0.65298 to 0.64980, saving model to small_weights.h5
# Epoch 30/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.4466 - accuracy: 0.8898 - val_loss: 0.6144 - val_accuracy: 0.8643
#
# Epoch 00030: val_loss improved from 0.64980 to 0.61436, saving model to small_weights.h5
# Epoch 31/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.4183 - accuracy: 0.9032 - val_loss: 0.5917 - val_accuracy: 0.8649
#
# Epoch 00031: val_loss improved from 0.61436 to 0.59166, saving model to small_weights.h5
# Epoch 32/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.3979 - accuracy: 0.9113 - val_loss: 0.5989 - val_accuracy: 0.8707
#
# Epoch 00032: val_loss did not improve from 0.59166
# Epoch 33/40
# 242/242 [==============================] - 5s 21ms/step - loss: 0.3792 - accuracy: 0.9160 - val_loss: 0.5812 - val_accuracy: 0.8736
#
# Epoch 00033: val_loss improved from 0.59166 to 0.58118, saving model to small_weights.h5
# Epoch 34/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.3736 - accuracy: 0.9189 - val_loss: 0.5875 - val_accuracy: 0.8736
#
# Epoch 00034: val_loss did not improve from 0.58118
# Epoch 35/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.3622 - accuracy: 0.9241 - val_loss: 0.5806 - val_accuracy: 0.8730
#
# Epoch 00035: val_loss improved from 0.58118 to 0.58062, saving model to small_weights.h5
# Epoch 36/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.3527 - accuracy: 0.9289 - val_loss: 0.5878 - val_accuracy: 0.8754
#
# Epoch 00036: val_loss did not improve from 0.58062
# Epoch 37/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.3462 - accuracy: 0.9293 - val_loss: 0.5784 - val_accuracy: 0.8725
#
# Epoch 00037: val_loss improved from 0.58062 to 0.57841, saving model to small_weights.h5
# Epoch 38/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.3352 - accuracy: 0.9330 - val_loss: 0.5736 - val_accuracy: 0.8759
#
# Epoch 00038: val_loss improved from 0.57841 to 0.57357, saving model to small_weights.h5
# Epoch 39/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.3242 - accuracy: 0.9367 - val_loss: 0.5891 - val_accuracy: 0.8730
#
# Epoch 00039: val_loss did not improve from 0.57357
# Epoch 40/40
# 242/242 [==============================] - 5s 22ms/step - loss: 0.3254 - accuracy: 0.9357 - val_loss: 0.5609 - val_accuracy: 0.8748
#
# Epoch 00040: val_loss improved from 0.57357 to 0.56090, saving model to small_weights.h5

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#Load the best weights
model.load_weights('small_weights.h5')

# %%
y_pred = model.predict_classes(X_test)
print(y_pred)
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# [4 1 4 ... 4 2 3]

# %%
#Accuracy score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8725535880708295

# %%
#Classification report
print(classification_report(y_test, y_pred, digits = 5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.83929   0.86891   0.85384       595
#            1    0.85270   0.76966   0.80906       534
#            2    0.90149   0.91183   0.90663      1395
#            3    0.79322   0.70695   0.74760       331
#            4    0.92546   0.92619   0.92582      1260
#            5    0.63436   0.81356   0.71287       177
#
#     accuracy                        0.87255      4292
#    macro avg    0.82442   0.83285   0.82597      4292
# weighted avg    0.87447   0.87255   0.87255      4292

# %%
#Confusion Matrix
print('Confusion Matrix')
print(sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, fmt="d"))
# Out:
# Confusion Matrix
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
# Mapping of target classes using label-encoder
le_name_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(le_name_mapping)

emotional_class_mapping = []
for item in le_name_mapping.items():
    # print(key)
    emotional_class_mapping.append(item[0])

# print(emotional_class_mapping)
# Out:
# {'anger': 0, 'fear': 1, 'happy': 2, 'love': 3, 'sadness': 4, 'surprise': 5}

# %%
def predict_emotion(arg_string):
    review = re.sub('[^a-zA-Z]', ' ', arg_string)
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    onehot_repr = [one_hot(review, vocabulary_size)] 
    embed = pad_sequences(onehot_repr, padding='pre', maxlen = sentence_length)
    predicti = model.predict(embed)
    return emotional_class_mapping[np.argmax(predicti)]

# %%
predict_emotion('I am very happy and joyful today')
# Out:
# 'happy'

# %%
predict_emotion('Oh I love it')
# Out:
# 'love'

# %%
predict_emotion('The teacher is intimidating and scary')
# Out:
# 'fear'

# %%
predict_emotion('I am depressed')
# Out:
# 'sadness'

# %%
predict_emotion('I am quite furious')
# Out:
# 'anger'

# %%
predict_emotion('oh god what a surprise')
# Out:
# 'surprise'

# %%
predict_emotion('I am quite Amazed')
# Out:
# 'surprise'

# %%
predict_emotion('ohh my God')
# Out:
# 'surprise'
