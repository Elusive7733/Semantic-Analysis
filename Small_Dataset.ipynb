# %%
import numpy as np
import pandas as pd 
import tensorflow as tf
import nltk
import seaborn as sns
import re
import matplotlib.pyplot as plt
from tqdm import tqdm

from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
raw_data = pd.read_csv('small_dataset.csv') # Text data
EMBEDDING_FILE = f'glove.6B.100d.txt' # GloVe file path
raw_data.head()
# Out:
#                                                 Text  Emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
# Target Classes (Labels)
plt.figure(figsize=(15,5))

sns.countplot(raw_data['Emotion'])
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Emotion', ylabel='count'>

# %%
raw_data = raw_data.dropna()
X = raw_data.drop('Emotion',axis=1) # input
y = raw_data['Emotion'] # output

messages = X.copy()
messages.reset_index(inplace=True)

# %%
nltk.download('stopwords')
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Elusive\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []
for i in tqdm(range(0, len(messages))):
    review = re.sub('[^a-zA-Z]', ' ', messages['Text'][i]) #remove Special Characters
    review = review.lower() #lower case 
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')] #remove stopwords
    review = ' '.join(review)
    corpus.append(review)
# Out:
# 100%|██████████| 21459/21459 [01:32<00:00, 231.01it/s]

# %%
# Saving Progress
if len(corpus) > 10000:
    corpus_df = pd.DataFrame({'Text': corpus})
    corpus_df.to_csv('small_corpus.csv')
print(len(corpus))
corpus[-10:]
# Out:
# 21459
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
# Loading Progress
temp = pd.read_csv('small_corpus.csv')
temp['Emotion'] = raw_data['Emotion'].values
temp['Text'] = temp['Text'].str.replace('\d+', '')
temp = temp.dropna()
# Out:
# <ipython-input-10-fd0c2d5c437e>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   temp['Text'] = temp['Text'].str.replace('\d+', '')

# %%
temp_list = temp['Text'].tolist()
print(len(temp_list))
print(temp.shape)
temp_list[-10:]
# Out:
# 21458
# (21458, 3)
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
X = temp.drop('Emotion', axis=1) #input
y = temp['Emotion'] #output

# %%
corpus = []
corpus = temp_list
print(len(corpus))
corpus[-10:]
# Out:
# 21458
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
# Creating the dictionary with word as key and pretrained-value array as value
def get_coefs(word,*arr):
    return word, np.asarray(arr, dtype='float32')

embeddings_index = dict(get_coefs(*o.strip().split()) for o in open(EMBEDDING_FILE, encoding="utf8"))


# Calculate MEAN and Standard-Deviation for the pre-trained weights
all_embeddings = np.stack(embeddings_index.values())
embedding_mean, embedding_std = all_embeddings.mean(), all_embeddings.std()
print(embedding_mean, embedding_std)
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\IPython\core\interactiveshell.py:3357: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# 0.004451992 0.4081574

# %%
vocabulary_size = 13000 # Vocabulary size
embed_size = 100 #word vector size

tokenizer = Tokenizer(num_words = vocabulary_size)
tokenizer.fit_on_texts(list(corpus))

# %%
word_index = tokenizer.word_index # total words in the corpus
nb_words = min(vocabulary_size, len(word_index))

# Initialize weight matrix for embedding layer
embedding_matrix = np.random.normal(embedding_mean, embedding_std, (nb_words, embed_size)) 

for word, i in word_index.items():
    if i >= vocabulary_size:
        continue #skip the words if vocab size is reached
    embedding_vector = embeddings_index.get(word) #extracting the pre-trained values from GloVe
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
# Contains the pretrained GloVe weights for the words
len(embedding_matrix)
# Out:
# 13000

# %%
# One hot representation for input
onehot_repr=[one_hot(words, vocabulary_size) for words in corpus]

# Finding max words
l = 0
for x in corpus:
    l = max(l, len(x.split(' ')))

# Padding the sequences for input
sentence_length = l
embedded_docs = pad_sequences(onehot_repr, padding = 'pre', maxlen = sentence_length)
print(embedded_docs)
# Out:
# [[    0     0     0 ...  5681  1033  7146]
#  [    0     0     0 ...  6994  9702    96]
#  [    0     0     0 ...  1033 12934  1892]
#  ...
#  [    0     0     0 ...  9165  9268  7594]
#  [    0     0     0 ...    45  7594  7981]
#  [    0     0     0 ...     0  7594 11446]]

# %%
# Encoding the target outputs to integers
label_encoder = preprocessing.LabelEncoder()

X_final = np.array(embedded_docs) #input to array
y = label_encoder.fit_transform(y)
y_final=np.array(y)
print(y_final)

X_final.shape, y_final.shape
# Out:
# [4 4 0 ... 1 1 1]
# ((21458, 35), (21458,))

# %%
# Train-Test split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size = 0.2, random_state = 42) 

# Train-Validation split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.1, random_state = 21)

# %%
# Creating model
model = Sequential()
model.add(Embedding(vocabulary_size, embed_size, weights=[embedding_matrix]))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.3))
model.add(Dense(64, activation = 'relu')) #L1 regularization
model.add(Dropout(0.3))
model.add(Dense(6,activation = 'softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 100)         1300000
# _________________________________________________________________
# dropout_12 (Dropout)         (None, None, 100)         0
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 128)               84480
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 1,393,126
# Trainable params: 1,393,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_save = ModelCheckpoint('small_weights.h5', save_best_only = True, save_weights_only = True, monitor = 'val_loss', mode = 'min', verbose = 1)

history = model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 40, batch_size = 64, callbacks = [model_save])
# Out:
# Epoch 1/40
# 242/242 [==============================] - 8s 23ms/step - loss: 3.6055 - accuracy: 0.3225 - val_loss: 1.6715 - val_accuracy: 0.3273
#
# Epoch 00001: val_loss improved from inf to 1.67154, saving model to small_weights.h5
# Epoch 2/40
# 242/242 [==============================] - 5s 20ms/step - loss: 1.6391 - accuracy: 0.3201 - val_loss: 1.6300 - val_accuracy: 0.3273
#
# Epoch 00002: val_loss improved from 1.67154 to 1.62998, saving model to small_weights.h5
# Epoch 3/40
# 242/242 [==============================] - 5s 21ms/step - loss: 1.6138 - accuracy: 0.3238 - val_loss: 1.6181 - val_accuracy: 0.3273
#
# Epoch 00003: val_loss improved from 1.62998 to 1.61812, saving model to small_weights.h5
# Epoch 4/40
# 242/242 [==============================] - 5s 22ms/step - loss: 1.6088 - accuracy: 0.3270 - val_loss: 1.6161 - val_accuracy: 0.3273
#
# Epoch 00004: val_loss improved from 1.61812 to 1.61607, saving model to small_weights.h5
# Epoch 5/40
# 242/242 [==============================] - 5s 22ms/step - loss: 1.6052 - accuracy: 0.3245 - val_loss: 1.6154 - val_accuracy: 0.3273
#
# Epoch 00005: val_loss improved from 1.61607 to 1.61540, saving model to small_weights.h5
# Epoch 6/40
# 242/242 [==============================] - 5s 22ms/step - loss: 1.5929 - accuracy: 0.3280 - val_loss: 1.5154 - val_accuracy: 0.3273
#
# Epoch 00006: val_loss improved from 1.61540 to 1.51537, saving model to small_weights.h5
# Epoch 7/40
# 242/242 [==============================] - 5s 22ms/step - loss: 1.4217 - accuracy: 0.3614 - val_loss: 1.3290 - val_accuracy: 0.4065
#
# Epoch 00007: val_loss improved from 1.51537 to 1.32904, saving model to small_weights.h5
# Epoch 8/40
# 242/242 [==============================] - 5s 21ms/step - loss: 1.2783 - accuracy: 0.4207 - val_loss: 1.2519 - val_accuracy: 0.4228
#
# Epoch 00008: val_loss improved from 1.32904 to 1.25186, saving model to small_weights.h5
# Epoch 9/40
# 242/242 [==============================] - 5s 21ms/step - loss: 1.2207 - accuracy: 0.4330 - val_loss: 1.2039 - val_accuracy: 0.4327
#
# Epoch 00009: val_loss improved from 1.25186 to 1.20390, saving model to small_weights.h5
# Epoch 10/40
# 242/242 [==============================] - 5s 22ms/step - loss: 1.1756 - accuracy: 0.4456 - val_loss: 1.1789 - val_accuracy: 0.4380
#
# Epoch 00010: val_loss improved from 1.20390 to 1.17890, saving model to small_weights.h5
# Epoch 11/40
# 242/242 [==============================] - 5s 23ms/step - loss: 1.1346 - accuracy: 0.4592 - val_loss: 1.1451 - val_accuracy: 0.4554
#
# Epoch 00011: val_loss improved from 1.17890 to 1.14506, saving model to small_weights.h5
# Epoch 12/40
# 242/242 [==============================] - 5s 20ms/step - loss: 1.1005 - accuracy: 0.4789 - val_loss: 1.1085 - val_accuracy: 0.4834
#
# Epoch 00012: val_loss improved from 1.14506 to 1.10853, saving model to small_weights.h5
# Epoch 13/40
# 242/242 [==============================] - 5s 21ms/step - loss: 1.0558 - accuracy: 0.5012 - val_loss: 1.0955 - val_accuracy: 0.4910
#
# Epoch 00013: val_loss improved from 1.10853 to 1.09547, saving model to small_weights.h5
# Epoch 14/40
# 242/242 [==============================] - 6s 26ms/step - loss: 1.0156 - accuracy: 0.5240 - val_loss: 1.0409 - val_accuracy: 0.5347
#
# Epoch 00014: val_loss improved from 1.09547 to 1.04092, saving model to small_weights.h5
# Epoch 15/40
# 242/242 [==============================] - 8s 32ms/step - loss: 0.9303 - accuracy: 0.6239 - val_loss: 0.8227 - val_accuracy: 0.7135
#
# Epoch 00015: val_loss improved from 1.04092 to 0.82268, saving model to small_weights.h5
# Epoch 16/40
# 242/242 [==============================] - 8s 32ms/step - loss: 0.7489 - accuracy: 0.7475 - val_loss: 0.7298 - val_accuracy: 0.7536
#
# Epoch 00016: val_loss improved from 0.82268 to 0.72984, saving model to small_weights.h5
# Epoch 17/40
# 242/242 [==============================] - 8s 32ms/step - loss: 0.6780 - accuracy: 0.7738 - val_loss: 0.7188 - val_accuracy: 0.7670
#
# Epoch 00017: val_loss improved from 0.72984 to 0.71876, saving model to small_weights.h5
# Epoch 18/40
# 242/242 [==============================] - 7s 31ms/step - loss: 0.6306 - accuracy: 0.7877 - val_loss: 0.6915 - val_accuracy: 0.7711
#
# Epoch 00018: val_loss improved from 0.71876 to 0.69149, saving model to small_weights.h5
# Epoch 19/40
# 242/242 [==============================] - 8s 35ms/step - loss: 0.6040 - accuracy: 0.7996 - val_loss: 0.6787 - val_accuracy: 0.7810
#
# Epoch 00019: val_loss improved from 0.69149 to 0.67866, saving model to small_weights.h5
# Epoch 20/40
# 242/242 [==============================] - 8s 34ms/step - loss: 0.5738 - accuracy: 0.8110 - val_loss: 0.6725 - val_accuracy: 0.7740
#
# Epoch 00020: val_loss improved from 0.67866 to 0.67251, saving model to small_weights.h5
# Epoch 21/40
# 242/242 [==============================] - 8s 33ms/step - loss: 0.5625 - accuracy: 0.8140 - val_loss: 0.6637 - val_accuracy: 0.7857
#
# Epoch 00021: val_loss improved from 0.67251 to 0.66374, saving model to small_weights.h5
# Epoch 22/40
# 242/242 [==============================] - 8s 34ms/step - loss: 0.5462 - accuracy: 0.8207 - val_loss: 0.6523 - val_accuracy: 0.8014
#
# Epoch 00022: val_loss improved from 0.66374 to 0.65230, saving model to small_weights.h5
# Epoch 23/40
# 242/242 [==============================] - 8s 35ms/step - loss: 0.5325 - accuracy: 0.8254 - val_loss: 0.6567 - val_accuracy: 0.8119
#
# Epoch 00023: val_loss did not improve from 0.65230
# Epoch 24/40
# 242/242 [==============================] - 8s 34ms/step - loss: 0.5217 - accuracy: 0.8362 - val_loss: 0.6476 - val_accuracy: 0.8340
#
# Epoch 00024: val_loss improved from 0.65230 to 0.64756, saving model to small_weights.h5
# Epoch 25/40
# 242/242 [==============================] - 8s 35ms/step - loss: 0.4950 - accuracy: 0.8542 - val_loss: 0.6340 - val_accuracy: 0.8480
#
# Epoch 00025: val_loss improved from 0.64756 to 0.63403, saving model to small_weights.h5
# Epoch 26/40
# 242/242 [==============================] - 9s 35ms/step - loss: 0.4840 - accuracy: 0.8692 - val_loss: 0.6155 - val_accuracy: 0.8550
#
# Epoch 00026: val_loss improved from 0.63403 to 0.61549, saving model to small_weights.h5
# Epoch 27/40
# 242/242 [==============================] - 8s 35ms/step - loss: 0.4524 - accuracy: 0.8891 - val_loss: 0.5872 - val_accuracy: 0.8719
#
# Epoch 00027: val_loss improved from 0.61549 to 0.58717, saving model to small_weights.h5
# Epoch 28/40
# 242/242 [==============================] - 8s 35ms/step - loss: 0.4265 - accuracy: 0.9008 - val_loss: 0.5776 - val_accuracy: 0.8701
#
# Epoch 00028: val_loss improved from 0.58717 to 0.57761, saving model to small_weights.h5
# Epoch 29/40
# 242/242 [==============================] - 9s 36ms/step - loss: 0.4105 - accuracy: 0.9080 - val_loss: 0.5662 - val_accuracy: 0.8736
#
# Epoch 00029: val_loss improved from 0.57761 to 0.56617, saving model to small_weights.h5
# Epoch 30/40
# 242/242 [==============================] - 8s 35ms/step - loss: 0.3893 - accuracy: 0.9163 - val_loss: 0.5618 - val_accuracy: 0.8719
#
# Epoch 00030: val_loss improved from 0.56617 to 0.56184, saving model to small_weights.h5
# Epoch 31/40
# 242/242 [==============================] - 8s 34ms/step - loss: 0.3696 - accuracy: 0.9201 - val_loss: 0.5707 - val_accuracy: 0.8742
#
# Epoch 00031: val_loss did not improve from 0.56184
# Epoch 32/40
# 242/242 [==============================] - 9s 36ms/step - loss: 0.3570 - accuracy: 0.9235 - val_loss: 0.5645 - val_accuracy: 0.8771
#
# Epoch 00032: val_loss did not improve from 0.56184
# Epoch 33/40
# 242/242 [==============================] - 8s 35ms/step - loss: 0.3507 - accuracy: 0.9256 - val_loss: 0.5833 - val_accuracy: 0.8707
#
# Epoch 00033: val_loss did not improve from 0.56184
# Epoch 34/40
# 242/242 [==============================] - 8s 34ms/step - loss: 0.3302 - accuracy: 0.9320 - val_loss: 0.5673 - val_accuracy: 0.8829
#
# Epoch 00034: val_loss did not improve from 0.56184
# Epoch 35/40
# 242/242 [==============================] - 9s 35ms/step - loss: 0.3283 - accuracy: 0.9318 - val_loss: 0.5514 - val_accuracy: 0.8870
#
# Epoch 00035: val_loss improved from 0.56184 to 0.55137, saving model to small_weights.h5
# Epoch 36/40
# 242/242 [==============================] - 9s 35ms/step - loss: 0.3119 - accuracy: 0.9376 - val_loss: 0.5889 - val_accuracy: 0.8719
#
# Epoch 00036: val_loss did not improve from 0.55137
# Epoch 37/40
# 242/242 [==============================] - 8s 34ms/step - loss: 0.3030 - accuracy: 0.9375 - val_loss: 0.5732 - val_accuracy: 0.8759
#
# Epoch 00037: val_loss did not improve from 0.55137
# Epoch 38/40
# 242/242 [==============================] - 9s 36ms/step - loss: 0.2957 - accuracy: 0.9423 - val_loss: 0.5674 - val_accuracy: 0.8789
#
# Epoch 00038: val_loss did not improve from 0.55137
# Epoch 39/40
# 242/242 [==============================] - 9s 35ms/step - loss: 0.2883 - accuracy: 0.9463 - val_loss: 0.5806 - val_accuracy: 0.8794
#
# Epoch 00039: val_loss did not improve from 0.55137
# Epoch 40/40
# 242/242 [==============================] - 8s 35ms/step - loss: 0.2894 - accuracy: 0.9452 - val_loss: 0.5721 - val_accuracy: 0.8754
#
# Epoch 00040: val_loss did not improve from 0.55137

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#Load the best weights
model.load_weights('small_weights.h5')

# %%
y_pred = model.predict_classes(X_test)
print(y_pred)
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# [0 1 4 ... 4 2 3]

# %%
#Accuracy score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.880708294501398

# %%
#Classification report
print(classification_report(y_test, y_pred, digits = 5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.50091   0.92568   0.65006       296
#            1    0.34783   0.03042   0.05594       263
#            2    0.92285   0.87853   0.90014       708
#            3    0.71728   0.77401   0.74457       177
#            4    0.93627   0.92869   0.93247       617
#            5    0.67677   0.78824   0.72826        85
#
#     accuracy                        0.78332      2146
#    macro avg    0.68365   0.72093   0.66857      2146
# weighted avg    0.77134   0.78332   0.75184      2146

# %%
#Confusion Matrix
print('Confusion Matrix')
print(sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, fmt="d"))
# Out:
# Confusion Matrix
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
# Mapping of target classes using label-encoder
le_name_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(le_name_mapping)

emotional_class_mapping = []
for item in le_name_mapping.items():
    # print(key)
    emotional_class_mapping.append(item[0])

print(emotional_class_mapping)
# Out:
# {'anger': 0, 'fear': 1, 'happy': 2, 'love': 3, 'sadness': 4, 'surprise': 5}
# ['anger', 'fear', 'happy', 'love', 'sadness', 'surprise']

# %%
def predict_emotion(arg_string):
    review = re.sub('[^a-zA-Z]', ' ', arg_string)
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    onehot_repr = [one_hot(review, vocabulary_size)] 
    embed = pad_sequences(onehot_repr, padding='pre', maxlen = sentence_length)
    predicti = model.predict(embed)
    return emotional_class_mapping[np.argmax(predicti)]

# %%
predict_emotion('I am very happy and joyful today')
# Out:
# 'happy'

# %%
predict_emotion('He is an arrogant and rude person')
# Out:
# 'anger'

# %%
predict_emotion('The teacher is intimidating and scary')
# Out:
# 'anger'

# %%
predict_emotion('I am depressed')
# Out:
# 'sadness'

# %%
predict_emotion('I am loving this ice cream')
# Out:
# 'anger'

# %%
predict_emotion('I am quite furious')
# Out:
# 'anger'
