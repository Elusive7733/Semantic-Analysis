# %%
import numpy as np
import pandas as pd 
import tensorflow as tf
import nltk
import seaborn as sns
import re
import matplotlib.pyplot as plt
from tqdm import tqdm

from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
raw_data = pd.read_csv('small_dataset.csv') # Text data
EMBEDDING_FILE = f'glove.6B.100d.txt' # GloVe file path
raw_data.head()
# Out:
#                                                 Text  Emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
# Target Classes
sns.countplot(raw_data['Emotion'])
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Emotion', ylabel='count'>

# %%
raw_data = raw_data.dropna()
X = raw_data.drop('Emotion',axis=1) # input
y = raw_data['Emotion'] # output

messages = X.copy()
messages.reset_index(inplace=True)

# %%
nltk.download('stopwords')
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Elusive\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []
for i in tqdm(range(0, len(messages))):
    review = re.sub('[^a-zA-Z]', ' ', messages['Text'][i]) #remove Special Characters
    review = review.lower() #lower case 
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')] #remove stopwords
    review = ' '.join(review)
    corpus.append(review)
# Out:
# 100%|██████████| 21459/21459 [01:01<00:00, 347.89it/s]

# %%
corpus[-10:]
# Out:
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
# Creating the dictionary with word as key and pretrained-value array as value
def get_coefs(word,*arr):
    return word, np.asarray(arr, dtype='float32')

embeddings_index = dict(get_coefs(*o.strip().split()) for o in open(EMBEDDING_FILE, encoding="utf8"))


# Calculate MEAN and Standard-Deviation for the pre-trained weights
all_embeddings = np.stack(embeddings_index.values())
embedding_mean, embedding_std = all_embeddings.mean(), all_embeddings.std()
print(embedding_mean, embedding_std)
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\IPython\core\interactiveshell.py:3357: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# 0.004451992 0.4081574

# %%
vocabulary_size = 13000 # Vocabulary size
embed_size = 100 #word vector size

tokenizer = Tokenizer(num_words = vocabulary_size)
tokenizer.fit_on_texts(list(corpus))

# %%
word_index = tokenizer.word_index # total words in the corpus
nb_words = min(vocabulary_size, len(word_index))

# Initialize weight matrix for embedding layer
embedding_matrix = np.random.normal(embedding_mean, embedding_std, (nb_words, embed_size)) 

for word, i in word_index.items():
    if i >= vocabulary_size:
        continue #skip the words if vocab size is reached
    embedding_vector = embeddings_index.get(word) #extracting the pre-trained values from GloVe
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
# Contains the pretrained GloVe weights for the words
len(embedding_matrix)
# Out:
# 13000

# %%
# One hot representation for input
onehot_repr=[one_hot(words, vocabulary_size) for words in corpus]

# Finding max words
l = 0
for x in corpus:
    l = max(l, len(x.split(' ')))

# Padding the sequences for input
sentence_length = l
embedded_docs = pad_sequences(onehot_repr, padding = 'pre', maxlen = sentence_length)
print(embedded_docs)
# Out:
# [[    0     0     0 ... 10448  9794 12465]
#  [    0     0     0 ...  2076  5712  3415]
#  [    0     0     0 ...  9794   160  2071]
#  ...
#  [    0     0     0 ... 12459  2080 11796]
#  [    0     0     0 ...  9931 11796  8329]
#  [    0     0     0 ...     0 11796  5058]]

# %%
# Encoding the target outputs to integers
label_encoder = preprocessing.LabelEncoder()

X_final = np.array(embedded_docs) #input to array
y = label_encoder.fit_transform(y)
y_final=np.array(y)
print(y_final)

X_final.shape, y_final.shape
# Out:
# [4 4 0 ... 1 1 1]
# ((21459, 35), (21459,))

# %%
# Train-Test split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size = 0.1, random_state = 42) 

# Train-Validation split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.1, random_state = 21)

# %%
# Creating model
model = Sequential()
model.add(Embedding(vocabulary_size, embed_size, weights=[embedding_matrix]))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.3))
model.add(Dense(64, activation = 'relu', kernel_regularizer = tf.keras.regularizers.l1(0.01))) #L1 regularization
model.add(Dropout(0.3))
model.add(Dense(6,activation = 'softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 100)         1300000
# _________________________________________________________________
# dropout_9 (Dropout)          (None, None, 100)         0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 128)               84480
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 1,393,126
# Trainable params: 1,393,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_save = ModelCheckpoint('small_weights.h5', save_best_only = True, save_weights_only = True, monitor = 'val_loss', mode = 'min', verbose = 1)

history = model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 40, batch_size = 64, callbacks = [model_save])
# Out:
# Epoch 1/40
# 272/272 [==============================] - 8s 22ms/step - loss: 3.3722 - accuracy: 0.3227 - val_loss: 1.6307 - val_accuracy: 0.3452
#
# Epoch 00001: val_loss improved from inf to 1.63073, saving model to small_weights.h5
# Epoch 2/40
# 272/272 [==============================] - 5s 19ms/step - loss: 1.6287 - accuracy: 0.3274 - val_loss: 1.6073 - val_accuracy: 0.3452
#
# Epoch 00002: val_loss improved from 1.63073 to 1.60731, saving model to small_weights.h5
# Epoch 3/40
# 272/272 [==============================] - 5s 19ms/step - loss: 1.5958 - accuracy: 0.3285 - val_loss: 1.5028 - val_accuracy: 0.3618
#
# Epoch 00003: val_loss improved from 1.60731 to 1.50283, saving model to small_weights.h5
# Epoch 4/40
# 272/272 [==============================] - 5s 18ms/step - loss: 1.4322 - accuracy: 0.3733 - val_loss: 1.3151 - val_accuracy: 0.4374
#
# Epoch 00004: val_loss improved from 1.50283 to 1.31506, saving model to small_weights.h5
# Epoch 5/40
# 272/272 [==============================] - 5s 19ms/step - loss: 1.3077 - accuracy: 0.4255 - val_loss: 1.2531 - val_accuracy: 0.4431
#
# Epoch 00005: val_loss improved from 1.31506 to 1.25307, saving model to small_weights.h5
# Epoch 6/40
# 272/272 [==============================] - 5s 19ms/step - loss: 1.2377 - accuracy: 0.4593 - val_loss: 1.2099 - val_accuracy: 0.4653
#
# Epoch 00006: val_loss improved from 1.25307 to 1.20990, saving model to small_weights.h5
# Epoch 7/40
# 272/272 [==============================] - 5s 20ms/step - loss: 1.1489 - accuracy: 0.5423 - val_loss: 1.0755 - val_accuracy: 0.6134
#
# Epoch 00007: val_loss improved from 1.20990 to 1.07549, saving model to small_weights.h5
# Epoch 8/40
# 272/272 [==============================] - 6s 20ms/step - loss: 0.9921 - accuracy: 0.6504 - val_loss: 0.9073 - val_accuracy: 0.6925
#
# Epoch 00008: val_loss improved from 1.07549 to 0.90729, saving model to small_weights.h5
# Epoch 9/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.8754 - accuracy: 0.6987 - val_loss: 0.8140 - val_accuracy: 0.7215
#
# Epoch 00009: val_loss improved from 0.90729 to 0.81404, saving model to small_weights.h5
# Epoch 10/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.7986 - accuracy: 0.7274 - val_loss: 0.7750 - val_accuracy: 0.7433
#
# Epoch 00010: val_loss improved from 0.81404 to 0.77505, saving model to small_weights.h5
# Epoch 11/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.7416 - accuracy: 0.7452 - val_loss: 0.7357 - val_accuracy: 0.7552
#
# Epoch 00011: val_loss improved from 0.77505 to 0.73566, saving model to small_weights.h5
# Epoch 12/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.6997 - accuracy: 0.7619 - val_loss: 0.7070 - val_accuracy: 0.7629
#
# Epoch 00012: val_loss improved from 0.73566 to 0.70698, saving model to small_weights.h5
# Epoch 13/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.6619 - accuracy: 0.7758 - val_loss: 0.6751 - val_accuracy: 0.7712
#
# Epoch 00013: val_loss improved from 0.70698 to 0.67513, saving model to small_weights.h5
# Epoch 14/40
# 272/272 [==============================] - 6s 20ms/step - loss: 0.6290 - accuracy: 0.7874 - val_loss: 0.6782 - val_accuracy: 0.7728
#
# Epoch 00014: val_loss did not improve from 0.67513
# Epoch 15/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.6047 - accuracy: 0.7949 - val_loss: 0.6882 - val_accuracy: 0.7723
#
# Epoch 00015: val_loss did not improve from 0.67513
# Epoch 16/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.5852 - accuracy: 0.8050 - val_loss: 0.6707 - val_accuracy: 0.7826
#
# Epoch 00016: val_loss improved from 0.67513 to 0.67072, saving model to small_weights.h5
# Epoch 17/40
# 272/272 [==============================] - 5s 18ms/step - loss: 0.5759 - accuracy: 0.8069 - val_loss: 0.6699 - val_accuracy: 0.7811
#
# Epoch 00017: val_loss improved from 0.67072 to 0.66990, saving model to small_weights.h5
# Epoch 18/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.5564 - accuracy: 0.8104 - val_loss: 0.6568 - val_accuracy: 0.7899
#
# Epoch 00018: val_loss improved from 0.66990 to 0.65676, saving model to small_weights.h5
# Epoch 19/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.5381 - accuracy: 0.8216 - val_loss: 0.6534 - val_accuracy: 0.8043
#
# Epoch 00019: val_loss improved from 0.65676 to 0.65339, saving model to small_weights.h5
# Epoch 20/40
# 272/272 [==============================] - 5s 19ms/step - loss: 0.5220 - accuracy: 0.8357 - val_loss: 0.6485 - val_accuracy: 0.8261
#
# Epoch 00020: val_loss improved from 0.65339 to 0.64848, saving model to small_weights.h5
# Epoch 21/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.4988 - accuracy: 0.8615 - val_loss: 0.6058 - val_accuracy: 0.8592
#
# Epoch 00021: val_loss improved from 0.64848 to 0.60582, saving model to small_weights.h5
# Epoch 22/40
# 272/272 [==============================] - 5s 18ms/step - loss: 0.4682 - accuracy: 0.8786 - val_loss: 0.5906 - val_accuracy: 0.8613
#
# Epoch 00022: val_loss improved from 0.60582 to 0.59062, saving model to small_weights.h5
# Epoch 23/40
# 272/272 [==============================] - 5s 18ms/step - loss: 0.4496 - accuracy: 0.8851 - val_loss: 0.5823 - val_accuracy: 0.8628
#
# Epoch 00023: val_loss improved from 0.59062 to 0.58227, saving model to small_weights.h5
# Epoch 24/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.4236 - accuracy: 0.8976 - val_loss: 0.6010 - val_accuracy: 0.8659
#
# Epoch 00024: val_loss did not improve from 0.58227
# Epoch 25/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.3967 - accuracy: 0.9083 - val_loss: 0.5921 - val_accuracy: 0.8737
#
# Epoch 00025: val_loss did not improve from 0.58227
# Epoch 26/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.3956 - accuracy: 0.9078 - val_loss: 0.5869 - val_accuracy: 0.8690
#
# Epoch 00026: val_loss did not improve from 0.58227
# Epoch 27/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.3782 - accuracy: 0.9157 - val_loss: 0.5751 - val_accuracy: 0.8711
#
# Epoch 00027: val_loss improved from 0.58227 to 0.57514, saving model to small_weights.h5
# Epoch 28/40
# 272/272 [==============================] - 5s 18ms/step - loss: 0.3677 - accuracy: 0.9169 - val_loss: 0.6152 - val_accuracy: 0.8665
#
# Epoch 00028: val_loss did not improve from 0.57514
# Epoch 29/40
# 272/272 [==============================] - 6s 20ms/step - loss: 0.3489 - accuracy: 0.9270 - val_loss: 0.5843 - val_accuracy: 0.8716
#
# Epoch 00029: val_loss did not improve from 0.57514
# Epoch 30/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.3387 - accuracy: 0.9310 - val_loss: 0.5820 - val_accuracy: 0.8732
#
# Epoch 00030: val_loss did not improve from 0.57514
# Epoch 31/40
# 272/272 [==============================] - 6s 20ms/step - loss: 0.3305 - accuracy: 0.9323 - val_loss: 0.6049 - val_accuracy: 0.8727
#
# Epoch 00031: val_loss did not improve from 0.57514
# Epoch 32/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.3274 - accuracy: 0.9327 - val_loss: 0.6019 - val_accuracy: 0.8753
#
# Epoch 00032: val_loss did not improve from 0.57514
# Epoch 33/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.3171 - accuracy: 0.9365 - val_loss: 0.6024 - val_accuracy: 0.8706
#
# Epoch 00033: val_loss did not improve from 0.57514
# Epoch 34/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.3096 - accuracy: 0.9391 - val_loss: 0.6403 - val_accuracy: 0.8690
#
# Epoch 00034: val_loss did not improve from 0.57514
# Epoch 35/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.3013 - accuracy: 0.9424 - val_loss: 0.6294 - val_accuracy: 0.8742
#
# Epoch 00035: val_loss did not improve from 0.57514
# Epoch 36/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.2934 - accuracy: 0.9429 - val_loss: 0.5956 - val_accuracy: 0.8716
#
# Epoch 00036: val_loss did not improve from 0.57514
# Epoch 37/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.2827 - accuracy: 0.9453 - val_loss: 0.6170 - val_accuracy: 0.8763
#
# Epoch 00037: val_loss did not improve from 0.57514
# Epoch 38/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.2812 - accuracy: 0.9474 - val_loss: 0.6092 - val_accuracy: 0.8763
#
# Epoch 00038: val_loss did not improve from 0.57514
# Epoch 39/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.2698 - accuracy: 0.9499 - val_loss: 0.6165 - val_accuracy: 0.8727
#
# Epoch 00039: val_loss did not improve from 0.57514
# Epoch 40/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.2712 - accuracy: 0.9500 - val_loss: 0.6183 - val_accuracy: 0.8706
#
# Epoch 00040: val_loss did not improve from 0.57514

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#Load the best weights
model.load_weights('small_weights.h5')

# %%
y_pred = model.predict_classes(X_test)
print(y_pred)
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# [2 0 1 ... 2 3 2]

# %%
#Accuracy score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.885834109972041

# %%
#Classification report
print(classification_report(y_test, y_pred, digits = 5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.87805   0.91429   0.89580       315
#            1    0.82847   0.82246   0.82545       276
#            2    0.92683   0.89676   0.91154       678
#            3    0.68862   0.80986   0.74434       142
#            4    0.94531   0.92934   0.93726       651
#            5    0.71605   0.69048   0.70303        84
#
#     accuracy                        0.88583      2146
#    macro avg    0.83055   0.84386   0.83624      2146
# weighted avg    0.88861   0.88583   0.88674      2146

# %%
#Confusion Matrix
print('Confusion Matrix')
print(sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, fmt="d"))
# Out:
# Confusion Matrix
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
#Mapping of target classes using label-encoder
le_name_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
le_name_mapping = {'anger': 0, 'fear': 1, 'happy': 2, 'love': 3, 'sadness': 4, 'surprise': 5}
print(le_name_mapping)

emotional_class_mapping = []
for item in le_name_mapping.items():
    # print(key)
    emotional_class_mapping.append(item[0])

print(emotional_class_mapping)
# Out:
# {'anger': 0, 'fear': 1, 'happy': 2, 'love': 3, 'sadness': 4, 'surprise': 5}
# ['anger', 'fear', 'happy', 'love', 'sadness', 'surprise']

# %%
def predict_emotion(arg_string):
    review = re.sub('[^a-zA-Z]', ' ', arg_string)
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    onehot_repr = [one_hot(review, vocabulary_size)] 
    embed = pad_sequences(onehot_repr,padding='pre',maxlen = sentence_length)
    predicti = model.predict(embed)
    return emotional_class_mapping[np.argmax(predicti)]

# %%
predict_emotion('I am very happy and joyful today')
# Out:
# 'happy'

# %%
predict_emotion('He is an arrogant and rude person')
# Out:
# 'anger'

# %%
predict_emotion('The teacher is intimidating and scary')
# Out:
# 'fear'

# %%
predict_emotion('I am depressed')
# Out:
# 'sadness'

# %%
predict_emotion('She is so adorable')
# Out:
# 'fear'
