# %%
import numpy as np
import pandas as pd 
import tensorflow as tf
import nltk
import seaborn as sns
import re
import matplotlib.pyplot as plt
from tqdm import tqdm

from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
raw_data = pd.read_csv('small_dataset.csv') # Text data
EMBEDDING_FILE = f'glove.6B.100d.txt' # GloVe file path
raw_data.head()
# Out:
#                                                 Text  Emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
# Target Classes (Labels)
plt.figure(figsize=(15,5))

sns.countplot(raw_data['Emotion'])
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Emotion', ylabel='count'>

# %%
raw_data = raw_data.dropna()
X = raw_data.drop('Emotion',axis=1) # input
y = raw_data['Emotion'] # output

messages = X.copy()
messages.reset_index(inplace=True)

# %%
nltk.download('stopwords')
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Elusive\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []
for i in tqdm(range(0, len(messages))):
    review = re.sub('[^a-zA-Z]', ' ', messages['Text'][i]) #remove Special Characters
    review = review.lower() #lower case 
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')] #remove stopwords
    review = ' '.join(review)
    corpus.append(review)
# Out:
# 100%|██████████| 21459/21459 [01:32<00:00, 231.01it/s]

# %%
# Saving Progress
if len(corpus) > 10000:
    corpus_df = pd.DataFrame({'Text': corpus})
    corpus_df.to_csv('small_corpus.csv')
print(len(corpus))
corpus[-10:]
# Out:
# 21459
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
# Loading Progress
temp = pd.read_csv('small_corpus.csv')
temp['Emotion'] = raw_data['Emotion'].values
temp['Text'] = temp['Text'].str.replace('\d+', '')
temp = temp.dropna()
# Out:
# <ipython-input-10-fd0c2d5c437e>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   temp['Text'] = temp['Text'].str.replace('\d+', '')

# %%
temp_list = temp['Text'].tolist()
print(len(temp_list))
print(temp.shape)
temp_list[-10:]
# Out:
# 21458
# (21458, 3)
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
X = temp.drop('Emotion', axis=1) #input
y = temp['Emotion'] #output

# %%
corpus = []
corpus = temp_list
print(len(corpus))
corpus[-10:]
# Out:
# 21458
# ['edouard look felt sicken dism',
#  'tina children move school cecilia felt dismay guilti reli',
#  'felt dismay sorrow mani peopl countri share person good fortun',
#  'stare one anoth dismay sad small wicked friend neighbour strewn around mind like dirti confetti parti long pa',
#  'cleo stare content dism',
#  'melissa stare friend dism',
#  'success state elect seen govern parti pummel dismay electora',
#  'vincent irrit dismay',
#  'kendal hume turn back face dismay coup',
#  'dismay surpri']

# %%
# Creating the dictionary with word as key and pretrained-value array as value
def get_coefs(word,*arr):
    return word, np.asarray(arr, dtype='float32')

embeddings_index = dict(get_coefs(*o.strip().split()) for o in open(EMBEDDING_FILE, encoding="utf8"))


# Calculate MEAN and Standard-Deviation for the pre-trained weights
all_embeddings = np.stack(embeddings_index.values())
embedding_mean, embedding_std = all_embeddings.mean(), all_embeddings.std()
print(embedding_mean, embedding_std)
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\IPython\core\interactiveshell.py:3357: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# 0.004451992 0.4081574

# %%
vocabulary_size = 13000 # Vocabulary size
embed_size = 100 #word vector size

tokenizer = Tokenizer(num_words = vocabulary_size)
tokenizer.fit_on_texts(list(corpus))

# %%
word_index = tokenizer.word_index # total words in the corpus
nb_words = min(vocabulary_size, len(word_index))

# Initialize weight matrix for embedding layer
embedding_matrix = np.random.normal(embedding_mean, embedding_std, (nb_words, embed_size)) 

for word, i in word_index.items():
    if i >= vocabulary_size:
        continue #skip the words if vocab size is reached
    embedding_vector = embeddings_index.get(word) #extracting the pre-trained values from GloVe
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
# Contains the pretrained GloVe weights for the words
len(embedding_matrix)
# Out:
# 13000

# %%
# One hot representation for input
onehot_repr=[one_hot(words, vocabulary_size) for words in corpus]

# Finding max words
l = 0
for x in corpus:
    l = max(l, len(x.split(' ')))

# Padding the sequences for input
sentence_length = l
embedded_docs = pad_sequences(onehot_repr, padding = 'pre', maxlen = sentence_length)
print(embedded_docs)
# Out:
# [[    0     0     0 ...  5681  1033  7146]
#  [    0     0     0 ...  6994  9702    96]
#  [    0     0     0 ...  1033 12934  1892]
#  ...
#  [    0     0     0 ...  9165  9268  7594]
#  [    0     0     0 ...    45  7594  7981]
#  [    0     0     0 ...     0  7594 11446]]

# %%
# Encoding the target outputs to integers
label_encoder = preprocessing.LabelEncoder()

X_final = np.array(embedded_docs) #input to array
y = label_encoder.fit_transform(y)
y_final=np.array(y)
print(y_final)

X_final.shape, y_final.shape
# Out:
# [4 4 0 ... 1 1 1]
# ((21458, 35), (21458,))

# %%
# Train-Test split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size = 0.2, random_state = 42) 

# Train-Validation split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.1, random_state = 21)

# %%
# Creating model
model = Sequential()
model.add(Embedding(vocabulary_size, embed_size, weights=[embedding_matrix]))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.3))
model.add(Dense(64, activation = 'relu', kernel_regularizer = tf.keras.regularizers.l1(0.01), activity_regularizer = tf.keras.regularizers.L2(0.01))) #L1 regularization
model.add(Dropout(0.4))
model.add(Dense(6,activation = 'softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 100)         1300000
# _________________________________________________________________
# dropout_6 (Dropout)          (None, None, 100)         0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 128)               84480
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 1,393,126
# Trainable params: 1,393,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_save = ModelCheckpoint('small_weights.h5', save_best_only = True, save_weights_only = True, monitor = 'val_loss', mode = 'min', verbose = 1)

history = model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 40, batch_size = 64, callbacks = [model_save])
# Out:
# Epoch 1/40
# 272/272 [==============================] - 8s 19ms/step - loss: 3.3642 - accuracy: 0.3171 - val_loss: 1.6568 - val_accuracy: 0.3214
#
# Epoch 00001: val_loss improved from inf to 1.65682, saving model to small_weights.h5
# Epoch 2/40
# 272/272 [==============================] - 5s 17ms/step - loss: 1.6220 - accuracy: 0.3231 - val_loss: 1.6325 - val_accuracy: 0.3214
#
# Epoch 00002: val_loss improved from 1.65682 to 1.63249, saving model to small_weights.h5
# Epoch 3/40
# 272/272 [==============================] - 5s 19ms/step - loss: 1.6105 - accuracy: 0.3253 - val_loss: 1.6256 - val_accuracy: 0.3214
#
# Epoch 00003: val_loss improved from 1.63249 to 1.62557, saving model to small_weights.h5
# Epoch 4/40
# 272/272 [==============================] - 5s 17ms/step - loss: 1.6074 - accuracy: 0.3234 - val_loss: 1.6233 - val_accuracy: 0.3214
#
# Epoch 00004: val_loss improved from 1.62557 to 1.62327, saving model to small_weights.h5
# Epoch 5/40
# 272/272 [==============================] - 5s 19ms/step - loss: 1.6051 - accuracy: 0.3269 - val_loss: 1.6234 - val_accuracy: 0.3214
#
# Epoch 00005: val_loss did not improve from 1.62327
# Epoch 6/40
# 272/272 [==============================] - 6s 20ms/step - loss: 1.5967 - accuracy: 0.3266 - val_loss: 1.5656 - val_accuracy: 0.3214
#
# Epoch 00006: val_loss improved from 1.62327 to 1.56559, saving model to small_weights.h5
# Epoch 7/40
# 272/272 [==============================] - 5s 19ms/step - loss: 1.4411 - accuracy: 0.3323 - val_loss: 1.3749 - val_accuracy: 0.3711
#
# Epoch 00007: val_loss improved from 1.56559 to 1.37492, saving model to small_weights.h5
# Epoch 8/40
# 272/272 [==============================] - 6s 21ms/step - loss: 1.3131 - accuracy: 0.4002 - val_loss: 1.2894 - val_accuracy: 0.4172
#
# Epoch 00008: val_loss improved from 1.37492 to 1.28940, saving model to small_weights.h5
# Epoch 9/40
# 272/272 [==============================] - 6s 20ms/step - loss: 1.2463 - accuracy: 0.4258 - val_loss: 1.2567 - val_accuracy: 0.4229
#
# Epoch 00009: val_loss improved from 1.28940 to 1.25669, saving model to small_weights.h5
# Epoch 10/40
# 272/272 [==============================] - 5s 19ms/step - loss: 1.2033 - accuracy: 0.4338 - val_loss: 1.2217 - val_accuracy: 0.4327
#
# Epoch 00010: val_loss improved from 1.25669 to 1.22170, saving model to small_weights.h5
# Epoch 11/40
# 272/272 [==============================] - 5s 20ms/step - loss: 1.1761 - accuracy: 0.4389 - val_loss: 1.2070 - val_accuracy: 0.4343
#
# Epoch 00011: val_loss improved from 1.22170 to 1.20696, saving model to small_weights.h5
# Epoch 12/40
# 272/272 [==============================] - 6s 20ms/step - loss: 1.1519 - accuracy: 0.4438 - val_loss: 1.2000 - val_accuracy: 0.4384
#
# Epoch 00012: val_loss improved from 1.20696 to 1.20005, saving model to small_weights.h5
# Epoch 13/40
# 272/272 [==============================] - 5s 19ms/step - loss: 1.1268 - accuracy: 0.4486 - val_loss: 1.1833 - val_accuracy: 0.4457
#
# Epoch 00013: val_loss improved from 1.20005 to 1.18327, saving model to small_weights.h5
# Epoch 14/40
# 272/272 [==============================] - 5s 20ms/step - loss: 1.1010 - accuracy: 0.4637 - val_loss: 1.1611 - val_accuracy: 0.4772
#
# Epoch 00014: val_loss improved from 1.18327 to 1.16114, saving model to small_weights.h5
# Epoch 15/40
# 272/272 [==============================] - 6s 20ms/step - loss: 1.0780 - accuracy: 0.4807 - val_loss: 1.1345 - val_accuracy: 0.4793
#
# Epoch 00015: val_loss improved from 1.16114 to 1.13454, saving model to small_weights.h5
# Epoch 16/40
# 272/272 [==============================] - 6s 21ms/step - loss: 1.0539 - accuracy: 0.4892 - val_loss: 1.0998 - val_accuracy: 0.4922
#
# Epoch 00016: val_loss improved from 1.13454 to 1.09978, saving model to small_weights.h5
# Epoch 17/40
# 272/272 [==============================] - 6s 21ms/step - loss: 1.0269 - accuracy: 0.4955 - val_loss: 1.0834 - val_accuracy: 0.4953
#
# Epoch 00017: val_loss improved from 1.09978 to 1.08338, saving model to small_weights.h5
# Epoch 18/40
# 272/272 [==============================] - 6s 21ms/step - loss: 1.0043 - accuracy: 0.5044 - val_loss: 1.0657 - val_accuracy: 0.4969
#
# Epoch 00018: val_loss improved from 1.08338 to 1.06569, saving model to small_weights.h5
# Epoch 19/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.9822 - accuracy: 0.5120 - val_loss: 1.0566 - val_accuracy: 0.4959
#
# Epoch 00019: val_loss improved from 1.06569 to 1.05660, saving model to small_weights.h5
# Epoch 20/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.9589 - accuracy: 0.5314 - val_loss: 1.0310 - val_accuracy: 0.5890
#
# Epoch 00020: val_loss improved from 1.05660 to 1.03096, saving model to small_weights.h5
# Epoch 21/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.8799 - accuracy: 0.6410 - val_loss: 0.8742 - val_accuracy: 0.7241
#
# Epoch 00021: val_loss improved from 1.03096 to 0.87418, saving model to small_weights.h5
# Epoch 22/40
# 272/272 [==============================] - 5s 20ms/step - loss: 0.7354 - accuracy: 0.7560 - val_loss: 0.7668 - val_accuracy: 0.7572
#
# Epoch 00022: val_loss improved from 0.87418 to 0.76676, saving model to small_weights.h5
# Epoch 23/40
# 272/272 [==============================] - 6s 20ms/step - loss: 0.6574 - accuracy: 0.7869 - val_loss: 0.7348 - val_accuracy: 0.7676
#
# Epoch 00023: val_loss improved from 0.76676 to 0.73476, saving model to small_weights.h5
# Epoch 24/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.6200 - accuracy: 0.8016 - val_loss: 0.7451 - val_accuracy: 0.7660
#
# Epoch 00024: val_loss did not improve from 0.73476
# Epoch 25/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.5931 - accuracy: 0.8082 - val_loss: 0.7018 - val_accuracy: 0.7790
#
# Epoch 00025: val_loss improved from 0.73476 to 0.70180, saving model to small_weights.h5
# Epoch 26/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.5653 - accuracy: 0.8170 - val_loss: 0.7101 - val_accuracy: 0.7831
#
# Epoch 00026: val_loss did not improve from 0.70180
# Epoch 27/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.5545 - accuracy: 0.8167 - val_loss: 0.6895 - val_accuracy: 0.7816
#
# Epoch 00027: val_loss improved from 0.70180 to 0.68949, saving model to small_weights.h5
# Epoch 28/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.5386 - accuracy: 0.8221 - val_loss: 0.6673 - val_accuracy: 0.7852
#
# Epoch 00028: val_loss improved from 0.68949 to 0.66727, saving model to small_weights.h5
# Epoch 29/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.5178 - accuracy: 0.8258 - val_loss: 0.7064 - val_accuracy: 0.7852
#
# Epoch 00029: val_loss did not improve from 0.66727
# Epoch 30/40
# 272/272 [==============================] - 6s 21ms/step - loss: 0.5107 - accuracy: 0.8297 - val_loss: 0.7067 - val_accuracy: 0.7826
#
# Epoch 00030: val_loss did not improve from 0.66727
# Epoch 31/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.5039 - accuracy: 0.8330 - val_loss: 0.6986 - val_accuracy: 0.7816
#
# Epoch 00031: val_loss did not improve from 0.66727
# Epoch 32/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.4890 - accuracy: 0.8341 - val_loss: 0.6931 - val_accuracy: 0.7754
#
# Epoch 00032: val_loss did not improve from 0.66727
# Epoch 33/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.4789 - accuracy: 0.8352 - val_loss: 0.7044 - val_accuracy: 0.7800
#
# Epoch 00033: val_loss did not improve from 0.66727
# Epoch 34/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.4808 - accuracy: 0.8361 - val_loss: 0.7190 - val_accuracy: 0.7842
#
# Epoch 00034: val_loss did not improve from 0.66727
# Epoch 35/40
# 272/272 [==============================] - 6s 23ms/step - loss: 0.4653 - accuracy: 0.8398 - val_loss: 0.7231 - val_accuracy: 0.7821
#
# Epoch 00035: val_loss did not improve from 0.66727
# Epoch 36/40
# 272/272 [==============================] - 6s 23ms/step - loss: 0.4588 - accuracy: 0.8434 - val_loss: 0.7086 - val_accuracy: 0.7790
#
# Epoch 00036: val_loss did not improve from 0.66727
# Epoch 37/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.4521 - accuracy: 0.8411 - val_loss: 0.6976 - val_accuracy: 0.7847
#
# Epoch 00037: val_loss did not improve from 0.66727
# Epoch 38/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.4486 - accuracy: 0.8436 - val_loss: 0.7071 - val_accuracy: 0.7852
#
# Epoch 00038: val_loss did not improve from 0.66727
# Epoch 39/40
# 272/272 [==============================] - 6s 22ms/step - loss: 0.4426 - accuracy: 0.8444 - val_loss: 0.7219 - val_accuracy: 0.7857
#
# Epoch 00039: val_loss did not improve from 0.66727
# Epoch 40/40
# 272/272 [==============================] - 6s 23ms/step - loss: 0.4373 - accuracy: 0.8470 - val_loss: 0.7377 - val_accuracy: 0.7836
#
# Epoch 00040: val_loss did not improve from 0.66727

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#Load the best weights
model.load_weights('small_weights.h5')

# %%
y_pred = model.predict_classes(X_test)
print(y_pred)
# Out:
# C:\ProgramData\Anaconda3\envs\Dsci\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# [0 1 4 ... 2 1 0]

# %%
#Accuracy score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8890959925442684

# %%
#Classification report
print(classification_report(y_test, y_pred, digits = 5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.87708   0.89189   0.88442       296
#            1    0.84342   0.90114   0.87132       263
#            2    0.92996   0.88136   0.90500       708
#            3    0.72414   0.83051   0.77368       177
#            4    0.94859   0.92707   0.93770       617
#            5    0.73563   0.75294   0.74419        85
#
#     accuracy                        0.88910      2146
#    macro avg    0.84313   0.86415   0.85272      2146
# weighted avg    0.89274   0.88910   0.89024      2146

# %%
#Confusion Matrix
print('Confusion Matrix')
print(sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, fmt="d"))
# Out:
# Confusion Matrix
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
# Mapping of target classes using label-encoder
le_name_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(le_name_mapping)

emotional_class_mapping = []
for item in le_name_mapping.items():
    # print(key)
    emotional_class_mapping.append(item[0])

print(emotional_class_mapping)
# Out:
# {'anger': 0, 'fear': 1, 'happy': 2, 'love': 3, 'sadness': 4, 'surprise': 5}
# ['anger', 'fear', 'happy', 'love', 'sadness', 'surprise']

# %%
def predict_emotion(arg_string):
    review = re.sub('[^a-zA-Z]', ' ', arg_string)
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    onehot_repr = [one_hot(review, vocabulary_size)] 
    embed = pad_sequences(onehot_repr, padding='pre', maxlen = sentence_length)
    predicti = model.predict(embed)
    return emotional_class_mapping[np.argmax(predicti)]

# %%
predict_emotion('I am very happy and joyful today')
# Out:
# 'happy'

# %%
predict_emotion('He is an arrogant and rude person')
# Out:
# 'anger'

# %%
predict_emotion('The teacher is intimidating and scary')
# Out:
# 'fear'

# %%
predict_emotion('I am depressed')
# Out:
# 'sadness'

# %%
predict_emotion('I am loving this ice cream')
# Out:
# 'happy'

# %%
predict_emotion('I am quite furious')
# Out:
# 'anger'
